# %%
import pandas as pd
import numpy as np

# %%
from math import factorial

# %% [markdown]
# Случайная непрерывная величина A имеет равномерное распределение на промежутке (200, 800].
# Найдите ее среднее значение и дисперсию.

# %%
print(f"Среднее: {(200+800)/2}")
print(f"Дисперсия: {(800-200)**2/12}")
# Out:
# Среднее: 500.0
# Дисперсия: 30000.0

# %% [markdown]
# О случайной непрерывной равномерно распределенной величине B известно, что ее дисперсия равна 0.2.
# Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5?
# Если да, найдите ее.

# %%
a = 0.5
d = 0.2
b = (d * 12)**(1/2) + a
print(f"Правая граница {b}, среднее значение: {(a+b)/2}")
# Out:
# Правая граница 2.049193338482967, среднее значение: 1.2745966692414834

# %% [markdown]
# Непрерывная случайная величина X распределена нормально и задана плотностью распределения
# f(x) = (1 / (4 * sqrt(2*pi))) * (exp(-(x+2)**2) / 32).
# Найдите:
# а). M(X)
# б). D(X)
# в). std(X) (среднее квадратичное отклонение)

# %%
print(f"M(X): {-2};    D(X): {16};    std(X): {4}")
# Out:
# M(X): -2;    D(X): 16;    std(X): 4

# %% [markdown]
# Рост взрослого населения города X имеет нормальное распределение.
# Причем, средний рост равен 174 см, а среднее квадратичное отклонение равно 8 см.
# Какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
# а). больше 182 см
# б). больше 190 см
# в). от 166 см до 190 см
# г). от 166 см до 182 см
# д). от 158 см до 190 см
# е). не выше 150 см или не ниже 190 см
# ё). не выше 150 см или не ниже 198 см
# ж). ниже 166 см.

# %%
print("вероятность того, что случайным образом выбранный взрослый человек имеет рост: ")
print(f"а). больше 182 см - {16}%")
print(f"б). больше 190 см - {2.28}%")
print(f"в). от 166 см до 190 см - {(0.9772 + (0.8413-1))*100}%")
print(f"г). от 166 см до 182 см - {(0.8413 + (0.8413-1))*100}%")
print(f"д). от 158 см до 190 см - {(0.9772 + (0.9772-1))*100}%")
print(f"е). не выше 150 см или не ниже 190 см - {(1-0.9772+0.0014)*100}%")
print(f"ё). не выше 150 см или не ниже 198 см - {0.0014*2*100}%")
print(f"ж). ниже 166 см. - {0.01587*100}%")
# Out:
# вероятность того, что случайным образом выбранный взрослый человек имеет рост:
# а). больше 182 см - 16%
# б). больше 190 см - 2.28%
# в). от 166 см до 190 см - 81.85%
# г). от 166 см до 182 см - 68.26%
# д). от 158 см до 190 см - 95.44%
# е). не выше 150 см или не ниже 190 см - 2.420000000000004%
# ё). не выше 150 см или не ниже 198 см - 0.27999999999999997%
# ж). ниже 166 см. - 1.587%

# %% [markdown]
# На сколько сигм (средних квадратичных отклонений) отклоняется рост человека, равный 190 см, от
# математического ожидания роста в популяции, в которой M(X) = 178 см и D(X) = 25 кв.см?

# %%
print(f"К-во сигм: {(190-178)/25**(1/2)}")
# Out:
# К-во сигм: 2.4
